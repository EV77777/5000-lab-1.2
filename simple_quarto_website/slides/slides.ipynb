# %% [markdown]
# # My week
#
# really really busy
#
# ## Class schedule
#
# ### DSA Classes
#
# [@10.1257/jep.27.2.3]
#
# ![](images/github-1.png)
# ![](images/photo2.png)

# %%
import matplotlib.pyplot as plt

x_start, y_start = 0, 0
x_end, y_end = 5, 5

fig, ax = plt.subplots()

# 绘制直线
ax.plot([x_start, x_end], [y_start, y_end], label='直线', linestyle='-', color='b')


# 显示图形
plt.show()
